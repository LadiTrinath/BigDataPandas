# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\svldi\\OneDrive\\Desktop\\employees.csv")
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df2=df.loc[df['Salary']>100000,:]
df2
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# 5       Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 9      Frances         B  Female  08-08-2002         6:51 AM  139852    7.524
# ..         ...       ...     ...         ...             ...     ...      ...
# 990      Robin         M  Female   7/24/1987         1:35 PM  100765   10.982
# 991       Rose         N  Female   8/25/2002         5:12 AM  134505   11.051
# 992    Anthony         A    Male  10/16/2011         8:35 AM  112769   11.625
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df2=df.loc[(df['Salary']>100000) & (df['Senior Management']==True),['First Name','Last Name']]
df2
# Out:
#     First Name Last Name
# 3        Jerry         H
# 4        Larry         G
# 9      Frances         B
# 11       Julie         H
# 12     Brandon         G
# ..         ...       ...
# 987     Gloria         H
# 990      Robin         M
# 991       Rose         N
# 992    Anthony         A
# 999     Albert         N
#
# [195 rows x 2 columns]

# %%
df2=df.loc[df['First Name'].str.contains('Ro',na=False)]
df2
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 45       Roger         F    Male   4/17/1980        11:32 AM   88010   13.886
# 78       Robin         M  Female  06-04-1983         3:15 PM  114797    5.965
# 187      Roger         H    Male  11/19/2004         3:55 PM   51430    6.460
# 195     Ronald         H    Male   4/30/2014         2:19 PM  121068   12.757
# 202      Roger         C    Male  11-08-1982         2:32 AM  140558    5.084
# 242     Robert         C    Male  10/27/1990         7:15 PM   38041   18.428
# 265        Roy         B    Male   9/23/2004         1:31 PM  101941    3.450
# 318        Roy         M    Male  08-06-2006         7:52 AM  148225    1.841
# 335     Robert         N    Male  11/18/2014         5:00 AM   85799   19.930
# 343     Ronald         N    Male   2/24/2009         2:09 PM   96633    4.990
# 387     Robert         H    Male  10/29/1994         4:26 AM  123294   19.894
# ...

# %%
df2=df.loc[(df['First Name']).str.contains('Ro',na=False) & (df['Last Name']=='C')]
df2
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 202      Roger         C    Male  11-08-1982         2:32 AM  140558    5.084
# 242     Robert         C    Male  10/27/1990         7:15 PM   38041   18.428
# 394      Robin         C  Female  01-08-1998         2:12 AM  111163    5.025
# 586       Rose         C  Female  10/30/2004         4:34 PM   56961    7.585
#
#     Senior Management         Team
# 202              True        Sales
# 242              True  Engineering
# 394              True      Product
# 586             False    Marketing

# %%
df2.shape
# Out:
# (4, 9)

# %%
df2=df.loc[df['Team']=='Engineering']
df2.shape
# Out:
# (92, 9)

# %%
df3=df.loc[:,['First Name','Last Name']]
df3
# Out:
#     First Name Last Name
# 0      Douglas         A
# 1       Thomas         B
# 2        Maria         C
# 3        Jerry         H
# 4        Larry         G
# ..         ...       ...
# 995      Henry         H
# 996    Phillip         G
# 997    Russell         F
# 998      Larry         M
# 999     Albert         N
#
# [1000 rows x 2 columns]

# %%
df['New_column']=df['First Name']+df['Last Name']

# %%
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df3=df['First Name']

# %%
df3
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 1000, dtype: object

# %%
df=df['First Name']

# %%
df
# Out:
# 0      Douglas
# 1       Thomas
# 2        Maria
# 3        Jerry
# 4        Larry
#         ...
# 995      Henry
# 996    Phillip
# 997    Russell
# 998      Larry
# 999     Albert
# Name: First Name, Length: 1000, dtype: object

# %%
df=pd.read_csv("C:\\Users\\svldi\\OneDrive\\Desktop\\employees.csv")
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df['new_col']=df['Salary']+(df['Bonus %']*df['Salary'])/100
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# customers who are s urvived male & female
# all population age>30 and embarked =c
# create new column age*survived+pclass
# create new col embarked +cabin

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_df=df.loc[df['Survived']==1,['Name','Survived','Sex']]
new_df.head()
# Out:
#                                                 Name  Survived     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1  female
# 2                             Heikkinen, Miss. Laina         1  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1  female
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  female
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1  female

# %%
new_df=df.loc[(df['Survived']==1) & (df['Sex']=='male'),['Name','Survived','Sex']]
new_df
# Out:
#                                 Name  Survived   Sex
# 17      Williams, Mr. Charles Eugene         1  male
# 21             Beesley, Mr. Lawrence         1  male
# 23      Sloper, Mr. William Thompson         1  male
# 36                  Mamee, Mr. Hanna         1  male
# 55                 Woolner, Mr. Hugh         1  male
# ..                               ...       ...   ...
# 838                  Chip, Mr. Chang         1  male
# 839             Marechal, Mr. Pierre         1  male
# 857           Daly, Mr. Peter Denis          1  male
# 869  Johnson, Master. Harold Theodor         1  male
# 889            Behr, Mr. Karl Howell         1  male
#
# [109 rows x 3 columns]

# %%
new_df=df.loc[(df['Survived']==1) & (df['Sex']=='female'),['Name','Survived','Sex']]
new_df
# Out:
#                                                   Name  Survived     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...         1  female
# 2                               Heikkinen, Miss. Laina         1  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)         1  female
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1  female
# 9                  Nasser, Mrs. Nicholas (Adele Achem)         1  female
# ..                                                 ...       ...     ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)         1  female
# 875                   Najib, Miss. Adele Kiamie "Jane"         1  female
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)         1  female
# 880       Shelley, Mrs. William (Imanita Parrish Hall)         1  female
# 887                       Graham, Miss. Margaret Edith         1  female
#
# [233 rows x 3 columns]

# %%
new_df=df.loc[(df['Age']>30) & (df['Embarked']=='C'),['Name','Embarked']]
new_df.head()
# Out:
#                                                  Name Embarked
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...        C
# 30                           Uruchurtu, Don. Manuel E        C
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)        C
# 54                     Ostby, Mr. Engelhart Cornelius        C
# 96                          Goldschmidt, Mr. George B        C

# %%
new_df=df[(df['Age']>30) & (df['Embarked']=='C')]
new_df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 30           31         0       1
# 52           53         1       1
# 54           55         0       1
# 96           97         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 30      0  PC 17601  27.7208   NaN        C
# 52      0  PC 17572  76.7292   D33        C
# 54      1    113509  61.9792   B30        C
# 96      0  PC 17754  34.6542    A5        C

# %%
df['new_column']=df['Age']*df['Survived']+df['Pclass']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_column
# 0      0         A/5 21171   7.2500   NaN        S         3.0
# 1      0          PC 17599  71.2833   C85        C        39.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        29.0
# ...

# %%
df['new_column']=df['Embarked']+df['Cabin']
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_column
# 0      0         A/5 21171   7.2500   NaN        S        NaN
# 1      0          PC 17599  71.2833   C85        C       CC85
# 2      0  STON/O2. 3101282   7.9250   NaN        S        NaN
# 3      0            113803  53.1000  C123        S      SC123
# ...

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
record = {
  
 'Name': ['Ankit', 'Amit', 'Aishwarya', 'Priyanka', 'Priya', 'Shaurya' ],
 'Age': [21, 19, 20, 18, 17, 21],
 'Stream': ['Math', 'Commerce', 'Science', 'Math', 'Math', 'Science'],
 'Percentage': [88, 92, 95, 70, 65, 78] }

# %%
df2=pd.DataFrame(record)
df2
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95
# 3   Priyanka   18      Math          70
# 4      Priya   17      Math          65
# 5    Shaurya   21   Science          78

# %%
df2=df2.loc[df2['Percentage']>80]
df2
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95

# %%
df2=df2[df2['Percentage']>80]
df2
# Out:
#         Name  Age    Stream  Percentage
# 0      Ankit   21      Math          88
# 1       Amit   19  Commerce          92
# 2  Aishwarya   20   Science          95

# %%
option=['Math','Commerce']
res=df2[df2['Stream'].isin(option)]

# %%
res
# Out:
# Empty DataFrame
# Columns: [Name, Age, Stream, Percentage]
# Index: []

# %%
df.rename(columns={'PassengerId':"CustomerId"},inplace=True)
df
# Out:
#      CustomerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 886         887         0       2
# 887         888         1       1
# 888         889         0       3
# 889         890         1       1
# 890         891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new_df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 30           31         0       1
# 52           53         1       1
# 54           55         0       1
# 96           97         0       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 96                          Goldschmidt, Mr. George B    male  71.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 30      0  PC 17601  27.7208   NaN        C
# 52      0  PC 17572  76.7292   D33        C
# 54      1    113509  61.9792   B30        C
# 96      0  PC 17754  34.6542    A5        C

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df.isnull()
# Out:
#      CustomerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0         False     False   False  False  False  False  False  False   False
# 1         False     False   False  False  False  False  False  False   False
# 2         False     False   False  False  False  False  False  False   False
# 3         False     False   False  False  False  False  False  False   False
# 4         False     False   False  False  False  False  False  False   False
# ..          ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886       False     False   False  False  False  False  False  False   False
# 887       False     False   False  False  False  False  False  False   False
# 888       False     False   False  False  False   True  False  False   False
# 889       False     False   False  False  False  False  False  False   False
# 890       False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# CustomerId      0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age           177
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin         687
# Embarked        2
# dtype: int64

# %%
df1 = pd.DataFrame({'Name':['Raju', 'Rani', 'Geeta', 'Sita', 'Sohit'],
                    'Marks':[80, 90, 75, 88, 59]})
  
    # creating another dataframe with different data
df2 = pd.DataFrame({'Name':['Raju', 'Divya', 'Geeta', 'Sita'],
                    'Grade':['A', 'A', 'B', 'A'],
                    'Rank':[3, 1, 4, 2 ],
                    'Gender':['Male', 'Female', 'Female', 'Female']})

# %%
df1
# Out:
#     Name  Marks
# 0   Raju     80
# 1   Rani     90
# 2  Geeta     75
# 3   Sita     88
# 4  Sohit     59

# %%
df2
# Out:
#     Name Grade  Rank  Gender
# 0   Raju     A     3    Male
# 1  Divya     A     1  Female
# 2  Geeta     B     4  Female
# 3   Sita     A     2  Female

# %%
df1.merge(df2[['Name','Grade','Rank']])
# Out:
#     Name  Marks Grade  Rank
# 0   Raju     80     A     3
# 1  Geeta     75     B     4
# 2   Sita     88     A     2

# %%
df1.merge(df2[['Name','Grade','Rank']])
# Out:
#     Name  Marks Grade  Rank
# 0   Raju     80     A     3
# 1  Geeta     75     B     4
# 2   Sita     88     A     2

# %%
df2.merge(df1[['Name']])
# Out:
#     Name Grade  Rank  Gender
# 0   Raju     A     3    Male
# 1  Geeta     B     4  Female
# 2   Sita     A     2  Female

# %%
 df1.merge(df2[['Name','Grade','Rank']],on='Name',how='right')
# Out:
#     Name  Marks Grade  Rank
# 0   Raju   80.0     A     3
# 1  Divya    NaN     A     1
# 2  Geeta   75.0     B     4
# 3   Sita   88.0     A     2

# %%
data1={'Name':['Jai','Trinath','Suresh','Ramesh','Naresh','Mahesh','Suresh','Nresh'],
       'Age':[47,34,25,43,54,26,54,55],
       'Address':['nagpur','kolhapur','Allahabad','Kannuaj','Junpur','Kanpur','Allahabad','Alligarh'],
       'Qualification':['Btech','Mca','bsc','Mcom','Bcom','ph.d','Mtech','Btech']}

df.groupby(['Name'])

# %%
df5=pd.DataFrame(data1)

# %%
df5
# Out:
#       Name  Age    Address Qualification
# 0      Jai   47     nagpur         Btech
# 1  Trinath   34   kolhapur           Mca
# 2   Suresh   25  Allahabad           bsc
# 3   Ramesh   43    Kannuaj          Mcom
# 4   Naresh   54     Junpur          Bcom
# 5   Mahesh   26     Kanpur          ph.d
# 6   Suresh   54  Allahabad         Mtech
# 7    Nresh   55   Alligarh         Btech

# %%
print(df5.groupby('Name').groups
# Out:
#   Cell In [88], line 1
#     print(df5.groupby('Name').groups
#                                     ^
# SyntaxError: incomplete input

# %%
data1={'Name':['Jai','Trinath','Suresh','Ramesh','Naresh','Mahesh','Suresh','Nresh'],
       'Age':[47,34,25,43,54,26,54,55],
       'Address':['nagpur','kolhapur','Allahabad','Kannuaj','Junpur','Kanpur','Allahabad','Alligarh'],
       'Qualification':['Btech','Mca','bsc','Mcom','Bcom','ph.d','Mtech','Btech']}

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [85], line 2
#       1 df.groupby(['Name'])
# ----> 2 print(df.groupby(['Name']),groups)
#
# NameError: name 'groups' is not defined

# %%
data1 = {'Name':['Jai', 'Anuj', 'Jai', 'Princi',
                 'Gaurav', 'Anuj', 'Princi', 'Abhi'],
        'Age':[27, 24, 22, 32,
               33, 36, 27, 32],
        'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj',
                   'Jaunpur', 'Kanpur', 'Allahabad', 'Aligarh'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd',
                         'B.Tech', 'B.com', 'Msc', 'MA']}
    
  
df = pd.DataFrame(data1)
df
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27     Nagpur           Msc
# 1    Anuj   24     Kanpur            MA
# 2     Jai   22  Allahabad           MCA
# 3  Princi   32    Kannuaj           Phd
# 4  Gaurav   33    Jaunpur        B.Tech
# 5    Anuj   36     Kanpur         B.com
# 6  Princi   27  Allahabad           Msc
# 7    Abhi   32    Aligarh            MA

# %%
df.groupby('Name')
print(df.groupby('Name').groups)
# Out:
# {'Abhi': [7], 'Anuj': [1, 5], 'Gaurav': [4], 'Jai': [0, 2], 'Princi': [3, 6]}

# %%
df = pd.DataFrame({'fff': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bbb': ['P', 'Q', 'R', 'P', 'Q', 'R'],
                   'baa': [2, 3, 4, 5, 6, 7],
                   'zzz': ['h', 'i', 'j', 'k', 'l', 'm']})

df.pivot(index='fff',columns='bbb',values=['baa','zzz'])
# Out:
#     baa       zzz
# bbb   P  Q  R   P  Q  R
# fff
# one   2  3  4   h  i  j
# two   5  6  7   k  l  m

# %%
s= pd.Series(["8", 6, "7.5", 3, "0.9"])

# %%
pd.to_numeric(s)
# Out:
# 0    8.0
# 1    6.0
# 2    7.5
# 3    3.0
# 4    0.9
# dtype: float64

# %%
s= pd.Series(["8", 6, "7.5", 3, "0.9"])
s.astype(str)
# Out:
# 0      8
# 1      6
# 2    7.5
# 3      3
# 4    0.9
# dtype: object

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.dtypes
# Out:
# dtype('O')

# %%
s= pd.Series([ 6, 3, 9])

# %%
s.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [110], line 1
# ----> 1 s.astype(int)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[100]
# Out:
# PassengerId                        101
# Survived                             0
# Pclass                               3
# Name           Petranec, Miss. Matilda
# Sex                             female
# Age                               28.0
# SibSp                                0
# Parch                                0
# Ticket                          349245
# Fare                            7.8958
# Cabin                              NaN
# Embarked                             S
# Name: 100, dtype: object

# %%
new_df=df.loc[90:110]

# %%
new_df
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 90            91         0       3                  Christmann, Mr. Emil
# 91            92         0       3            Andreasson, Mr. Paul Edvin
# 92            93         0       1           Chaffee, Mr. Herbert Fuller
# 93            94         0       3               Dean, Mr. Bertram Frank
# 94            95         0       3                     Coxon, Mr. Daniel
# 95            96         0       3           Shorney, Mr. Charles Joseph
# 96            97         0       1             Goldschmidt, Mr. George B
# 97            98         1       1       Greenfield, Mr. William Bertram
# 98            99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 99           100         0       2                     Kantor, Mr. Sinai
# 100          101         0       3               Petranec, Miss. Matilda
# 101          102         0       3      Petroff, Mr. Pastcho ("Pentcho")
# ...

# %%
df=pd.read_csv("C:\\Users\\svldi\\OneDrive\\Desktop\\employees.csv")

# %%
df.head()
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df['salary_buckets']='na'
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df.loc[(df['Salary']<50000) & (df['Salary']>0),['salary_buckets']]='0-50000'
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df.loc[(df['Salary']<100000) & (df['Salary']>=50000),['salary_buckets']]='50000-100000'
df.head()
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team salary_buckets
# 0              True        Marketing   50000-100000
# 1              True              NaN   50000-100000
# 2             False          Finance             na
# 3              True          Finance             na
# 4              True  Client Services             na

# %%
df.loc[df['Salary']>=100000,['salary_buckets']]='>100000'
df.head()
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team salary_buckets
# 0              True        Marketing   50000-100000
# 1              True              NaN   50000-100000
# 2             False          Finance        >100000
# 3              True          Finance        >100000
# 4              True  Client Services        >100000

# %%
if sm-false & salary <100000 eligible promotion,if sm-True & salary<100000 & gender female  eligible promotion
if sm-true & salry<150000 eligible else not eligible
# Out:
#   Cell In [12], line 1
#     if sm-false & salary <100000 eligible promotion,if sm-True & salary<100000 & gender female  eligible promotion
#                                  ^
# SyntaxError: invalid syntax

# %%
df['new_col']='na'
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5       Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7          NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13        Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17       Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
# ..         ...       ...     ...         ...             ...     ...      ...
# 973    Russell         F    Male  05-10-2013        11:08 PM  137359   11.105
# 977      Sarah         B  Female  12-04-1995         9:16 AM  124566    5.949
# 981      James         F    Male   1/15/1993         5:19 PM  148985   19.280
# 983       John         N    Male  12/23/1982        10:35 PM  146907   11.738
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
#
# ...

# %%
df.loc[(df['Senior Management']==False) & (df['Salary']<100000),['new_col']]='Promotion'
df.head()
# Out:
#    First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5      Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7         NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13       Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17      Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
#
#    Senior Management     Team salary_buckets new_col
# 2              False  Finance        >100000      na
# 5              False    Legal        >100000      na
# 7                NaN  Finance        0-50000      na
# 13             False    Sales        >100000      na
# 17             False  Product        >100000      na

# %%
df.loc[(df['Senior Management']==True) & (df['Salary']<100000) & (df['Gender']=='Female'),['new_col']]='Promotion'
df.head(10)
# Out:
#    First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5      Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7         NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13       Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17      Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
# 18      Diana         C  Female  10/23/1981        10:27 AM  132940   19.082
# 21    Matthew         F    Male  09-05-1995         2:12 AM  100612   13.645
# 23        NaN         N    Male   6/14/2012         4:19 PM  125792    5.042
# 25        NaN         B    Male  10-08-2012         1:12 AM   37076   18.576
# 27      Scott         H     NaN  07-11-1991         6:58 PM  122367    5.218
#
#    Senior Management             Team salary_buckets new_col
# 2              False          Finance        >100000      na
# ...

# %%
df.loc[(df['Senior Management']==True) & (df['Salary']<1500000),['new_col']]='Promotion'
df.head()
# Out:
#    First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5      Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7         NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13       Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17      Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
#
#    Senior Management     Team salary_buckets new_col
# 2              False  Finance        >100000      na
# 5              False    Legal        >100000      na
# 7                NaN  Finance        0-50000      na
# 13             False    Sales        >100000      na
# 17             False  Product        >100000      na

# %%
df.loc[df['Salary']>=1500000,['new_col']]='not eligible'
df.head()
# Out:
#    First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2       Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5      Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7         NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13       Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17      Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
#
#    Senior Management     Team salary_buckets new_col
# 2              False  Finance        >100000      na
# 5              False    Legal        >100000      na
# 7                NaN  Finance        0-50000      na
# 13             False    Sales        >100000      na
# 17             False  Product        >100000      na

# %%
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5       Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7          NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13        Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17       Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
# ..         ...       ...     ...         ...             ...     ...      ...
# 973    Russell         F    Male  05-10-2013        11:08 PM  137359   11.105
# 977      Sarah         B  Female  12-04-1995         9:16 AM  124566    5.949
# 981      James         F    Male   1/15/1993         5:19 PM  148985   19.280
# 983       John         N    Male  12/23/1982        10:35 PM  146907   11.738
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
#
# ...

# %%
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5       Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7          NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13        Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17       Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
# ..         ...       ...     ...         ...             ...     ...      ...
# 973    Russell         F    Male  05-10-2013        11:08 PM  137359   11.105
# 977      Sarah         B  Female  12-04-1995         9:16 AM  124566    5.949
# 981      James         F    Male   1/15/1993         5:19 PM  148985   19.280
# 983       John         N    Male  12/23/1982        10:35 PM  146907   11.738
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
#
# ...

# %%
df['new_col']='na'
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df.loc[(df['Senior Management']==False) & (df['Salary']<100000),['new_col']]='Promotion'
df.head()
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team new_col
# 0              True        Marketing      na
# 1              True              NaN      na
# 2             False          Finance      na
# 3              True          Finance      na
# 4              True  Client Services      na

# %%
df.loc[(df['Senior Management']==True) & (df['Salary']<100000) & (df['Gender']=='Female'),['new_col']]='Promotion'
df.head(10)
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 6       Ruby         M  Female   8/17/1987         4:20 PM   65476   10.012
# 7        NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 8     Angela         A  Female  11/22/2005         6:29 AM   95570   18.523
# 9    Frances         B  Female  08-08-2002         6:51 AM  139852    7.524
#
#   Senior Management                  Team    new_col
# 0              True             Marketing         na
# ...

# %%
df.loc[(df['Senior Management']==True) & (df['Salary']<1500000),['new_col']]='Promotion'
df.head()
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team    new_col
# 0              True        Marketing  Promotion
# 1              True              NaN  Promotion
# 2             False          Finance         na
# 3              True          Finance  Promotion
# 4              True  Client Services  Promotion

# %%
df2=df.loc[df['Senior Management']==True]
df2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 df2=df.loc[df['Senior Management']==True]
#       2 df2
#
# AttributeError: 'str' object has no attribute 'loc'

# %%
df.shape
# Out:
# (249, 11)

# %%
df=pd.read_csv("C:\\Users\\svldi\\OneDrive\\Desktop\\employees.csv")
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df['new_col']='na'
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df.loc[df['new_col']=='na',['new_col']]='Not eligible'
df.head()
# Out:
#   First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team       new_col
# 0              True        Marketing     Promotion
# 1              True              NaN     Promotion
# 2             False          Finance  Not eligible
# 3              True          Finance     Promotion
# 4              True  Client Services     Promotion

# %%
# Out:
# 'Not eligible'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [62], line 1
# ----> 1 df.loc[(df['Senior Management']==True) & (df['Salary']<1500000),['new_col']]='Promotion'
#       2 df.head()
#
# AttributeError: 'str' object has no attribute 'loc'

# %%
df=pd.read_csv("C:\\Users\\svldi\\OneDrive\\Desktop\\employees.csv")
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df=pd.read_csv("C:\\Users\\svldi\\OneDrive\\Desktop\\employees.csv")
df
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas         A    Male  08-06-1993        12:42 PM   97308    6.945
# 1       Thomas         B    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry         H    Male  03-04-2005         1:00 PM  138705    9.340
# 4        Larry         G    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...       ...     ...         ...             ...     ...      ...
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip         G    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell         F    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry         M    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert         N    Male   5/15/2012         6:24 PM  129949   10.169
#
# ...

# %%
df2=df.loc[df['new_col']=='Not eligible']
df2
# Out:
#     First Name Last Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria         C  Female   4/23/1993        11:17 AM  130590   11.858
# 5       Dennis         F    Male   4/18/1987         1:35 AM  115163   10.125
# 7          NaN         N  Female   7/20/2015        10:43 AM   45906   11.598
# 13        Gary         F    Male   1/27/2008        11:40 PM  109831    5.831
# 17       Shawn         B    Male  12-07-1986         7:45 PM  111737    6.414
# ..         ...       ...     ...         ...             ...     ...      ...
# 973    Russell         F    Male  05-10-2013        11:08 PM  137359   11.105
# 977      Sarah         B  Female  12-04-1995         9:16 AM  124566    5.949
# 981      James         F    Male   1/15/1993         5:19 PM  148985   19.280
# 983       John         N    Male  12/23/1982        10:35 PM  146907   11.738
# 995      Henry         H     NaN  11/23/2014         6:09 AM  132483   16.655
#
# ...

# %%
df2.shape
# Out:
# (249, 10)

# %%
new_df=df.groupby(['new_col']).agg({'Salary':'mean','new_col':'count'})
new_df
# Out:
#                      Salary  new_col
# new_col
# Not eligible  116927.514056      249
# Promotion      81953.701731      751

# %%
new_df=df.groupby(['Team']).agg({'Salary':'mean','Team':'count'})
new_df
# Out:
#                             Salary  Team
# Team
# Business Development  91866.316832   101
# Client Services       88224.424528   106
# Distribution          88500.466667    90
# Engineering           94269.195652    92
# Finance               92219.480392   102
# Human Resources       90944.527473    91
# Legal                 89303.613636    88
# Marketing             90435.591837    98
# Product               88665.505263    95
# Sales                 92173.436170    94

# %%
new_df=df.groupby(['Team','Gender']).agg({'Last Name':'count'})
new_df
# Out:
#                              Last Name
# Team                 Gender
# Business Development Female         50
#                      Male           40
# Client Services      Female         48
#                      Male           42
# Distribution         Female         37
#                      Male           35
# Engineering          Female         44
#                      Male           40
# Finance              Female         44
#                      Male           41
# Human Resources      Female         37
#                      Male           45
# Legal                Female         34
#                      Male           35
# Marketing            Female         40
#                      Male           41
# Product              Female         45
#                      Male           40
# Sales                Female         39
#                      Male           39

# %%
df.isnull().sum()
# Out:
# First Name            67
# Last Name              0
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# new_col                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Last Name          1000 non-null   object
#  2   Gender             855 non-null    object
#  3   Start Date         1000 non-null   object
#  4   Last Login Time    1000 non-null   object
#  5   Salary             1000 non-null   int64
#  6   Bonus %            1000 non-null   float64
#  7   Senior Management  933 non-null    object
#  8   Team               957 non-null    object
#  9   new_col            1000 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 78.2+ KB

# %%
new_df=df.groupby(['Team','Gender']).agg({'Gender':'count','Team':'count'})
new_df
# Out:
#                              Gender  Team
# Team                 Gender
# Business Development Female      50    50
#                      Male        40    40
# Client Services      Female      48    48
#                      Male        42    42
# Distribution         Female      37    37
#                      Male        35    35
# Engineering          Female      44    44
#                      Male        40    40
# Finance              Female      44    44
#                      Male        41    41
# Human Resources      Female      37    37
#                      Male        45    45
# Legal                Female      34    34
#                      Male        35    35
# Marketing            Female      40    40
#                      Male        41    41
# Product              Female      45    45
#                      Male        40    40
# Sales                Female      39    39
#                      Male        39    39
